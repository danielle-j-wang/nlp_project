# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import scattertext as st
from scattertext import CorpusFromPandas, produce_scattertext_explorer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from gensim import matutils, models

import re
import string
import spacy
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag, pos_tag_sents
from nltk.chunk import ne_chunk
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.decomposition import NMF
from sklearn.preprocessing import normalize

# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

sns.set(context = 'paper', style='white', font_scale = 0.8)

# %%
df = pd.read_csv('complaints-2021-12-05.csv')

# %%
df.head()
# Out:
#   Date received                      Product  \
# 0      03/25/19  Checking or savings account
# 1      07/12/19              Debt collection
# 2      11/12/21              Debt collection
# 3      08/30/19              Debt collection
# 4      06/21/19  Credit card or prepaid card
#
#                                   Sub-product  \
# 0                            Checking account
# 1                                  Other debt
# 2                                Medical debt
# 3                            Credit card debt
# 4  General-purpose credit card or charge card
#
#                                 Issue  \
# 0                 Managing an account
# 1   Attempts to collect debt not owed
# 2   Attempts to collect debt not owed
# 3   Attempts to collect debt not owed
# 4  Other features, terms, or problems
#
#                                       Sub-issue  \
# 0  Funds not handled or disbursed as instructed
# 1                                 Debt was paid
# 2                             Debt is not yours
# 3                             Debt is not yours
# 4                                 Other problem
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  In XXXX, I started receiving mail and phone ca...
# 4  In XX/XX/2019 I received a phone call from XXX...
#
#                              Company public response  \
# 0                                               None
# 1  Company disputes the facts presented in the co...
# 2                                               None
# 3                                               None
# 4  Company has responded to the consumer and the ...
#
#                                 Company State ZIP code            Tags  \
# 0                  JPMORGAN CHASE & CO.    IL    60610            None
# 1                        NRA Group, LLC    IL    60628            None
# 2  Kinum, Inc., Indianapolis, IN Branch    IL    60620  Older American
# 3       Resurgent Capital Services L.P.    IL    62205            None
# 4                   SYNCHRONY FINANCIAL    IL    60643            None
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Fax             03/27/19
# 1       Consent not provided           Web             07/12/19
# 2                        NaN         Phone             11/12/21
# 3           Consent provided           Web             08/30/19
# 4           Consent provided           Web             06/21/19
#
#   Company response to consumer Timely response?  Consumer disputed?  \
# 0      Closed with explanation              Yes                 NaN
# 1      Closed with explanation              Yes                 NaN
# 2      Closed with explanation              Yes                 NaN
# 3      Closed with explanation              Yes                 NaN
# 4      Closed with explanation              Yes                 NaN
#
#    Complaint ID
# 0       3190068
# 1       3304855
# 2       4903716
# 3       3359230
# 4       3282179

# %% [markdown]
# ### EDA

# %%
df = df.rename(columns=str.lower)

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['date_received', 'product', 'sub-product', 'issue', 'sub-issue',
#        'consumer_complaint_narrative', 'company_public_response', 'company',
#        'state', 'zip_code', 'tags', 'consumer_consent_provided?',
#        'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
#        'timely_response?', 'consumer_disputed?', 'complaint_id'],
#       dtype='object')

# %%
df.consumer_complaint_narrative.isna().sum()
# Out:
# 8276

# %%
df.shape
# Out:
# (16122, 18)

# %%
df.dropna(subset=['consumer_complaint_narrative'], inplace=True)

# %%
df.shape
# Out:
# (7846, 18)

# %%
df.consumer_complaint_narrative.isna().sum()
# Out:
# 0

# %%
df.drop_duplicates('complaint_id', inplace=True) #df.duplicated(subset=['PaperID', 'Abstract'], keep=False).sum()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.duplicated(subset=['date_received', 'product', 'sub-product', 'issue', 'sub-issue',
       'consumer_complaint_narrative', 'company_public_response', 'company',
       'state', 'zip_code', 'tags', 'consumer_consent_provided?',
       'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
       'timely_response?', 'consumer_disputed?', 'complaint_id'], keep='first'). value_counts()
# Out:
# False    7846
# dtype: int64

# %%
df.sample(5)
# Out:
#      date_received                      product  \
# 1545      09/06/21              Debt collection
# 1561      02/18/19                 Student loan
# 2310      03/28/19        Vehicle loan or lease
# 663       02/18/20  Credit card or prepaid card
# 1779      12/28/18  Checking or savings account
#
#                                      sub-product  \
# 1545                               Mortgage debt
# 1561                        Private student loan
# 2310                                        Loan
# 663   General-purpose credit card or charge card
# 1779                            Checking account
#
#                                                   issue  \
# 1545  Took or threatened to take negative or legal a...
# 1561               Dealing with your lender or servicer
# 2310           Problems at the end of the loan or lease
# 663   Advertising and marketing, including promotion...
# 1779                                Managing an account
#
#                                               sub-issue  \
# 1545  Threatened or suggested your credit would be d...
# 1561                      Problem with customer service
# 2310                     Problem related to refinancing
# 663      Didn't receive advertised or promotional terms
# 1779                           Deposits and withdrawals
#
#                            consumer_complaint_narrative  \
# 1545  Fay services account # XXXX began foreclosure ...
# 1561  I have been trying to get in touch Conduent ( ...
# 2310  I over pay my XXXX  off pay for XXXX .toXXXX X...
# 663   I received a ''Premium Rewards '' from BMO on ...
# 1779  i had an account with US Bank which i opened i...
#
#                                 company_public_response  \
# 1545                                               None
# 1561  Company has responded to the consumer and the ...
# 2310                                               None
# 663   Company has responded to the consumer and the ...
# 1779  Company has responded to the consumer and the ...
#
#                                    company state zip_code           tags  \
# 1545                    Fay Servicing, LLC    IL    60449           None
# 1561                ACS Education Services    IL    60659           None
# 2310                Westlake Services, LLC    IL    60085  Servicemember
# 663   BMO HARRIS BANK NATIONAL ASSOCIATION    IL    61820           None
# 1779                          U.S. BANCORP    IL    60453           None
#
#      consumer_consent_provided? submitted_via date_sent_to_company  \
# 1545           Consent provided           Web             09/22/21
# 1561           Consent provided           Web             02/26/19
# 2310           Consent provided           Web             03/28/19
# 663            Consent provided           Web             02/18/20
# 1779           Consent provided           Web             12/28/18
#
#          company_response_to_consumer timely_response?  consumer_disputed?  \
# 1545          Closed with explanation              Yes                 NaN
# 1561          Closed with explanation              Yes                 NaN
# 2310          Closed with explanation              Yes                 NaN
# 663   Closed with non-monetary relief              Yes                 NaN
# 1779          Closed with explanation              Yes                 NaN
#
#       complaint_id
# 1545       4695921
# 1561       3155138
# 2310       3194094
# 663        3534853
# 1779       3111418

# %%
df.drop(['state', 'consumer_consent_provided?', 
         'submitted_via', 'date_sent_to_company', 'complaint_id'], axis=1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[5, 'consumer_complaint_narrative']
# Out:
# 'I opened a Checking account in Chase Bank on XX/XX/2019. I opened it online and there was an offer that if I make direct deposit of {$500.00} in first 60 days of account opening, then I will get bonus of {$200.00} within 10 days. While opening the account online, it says " COUPON APPLIED AUTOMATICALLY \'\' so i don\'t need to apply any coupon or visit the branch for the same. My first direct deposit was made on XX/XX/2019 ( {$2000.00} approx ). After that second direct deposit was made on XX/XX/2019 ( Almost same amount ). But I didn\'t get my bonus. I called customer care on XX/XX/2019 to enquire my bonus, they said that I did not applied coupon so I will not get the bonus. I explained them that the website is saying that coupon is automatically applied. Then they asked me to visit branch. I visited the branch on XX/XX/2019 and meet the relationship officer " XXXX XXXX \'\'. She said that as I opened account online so branch has nothing to do in it and sent an email to branch manager Mr. XXXX XXXX. Address of branch is XXXX XXXX XXXX XXXX XXXX, Il-XXXX. I got a call from the manager on XX/XX/2019 regarding same and he also tell me the same story of coupon. If the coupon is not applied, then it is the glitch on the bank end, then why should I suffer. \nPlease help me to get my bonus. \nThanks. \nXXXX XXXX XXXX'

# %% [markdown]
# ### Data Acquisition

# %%
corpus_check = df.consumer_complaint_narrative

# %%
sum([len(d.split(' ')) for d in corpus_check]) > 100000 # check for data acquisition requirement
# Out:
# True

# %%
df.to_csv('complaints.csv', index=False)

# %% [markdown]
# ### Text Preprocessing

# %%
# remove numbers, punctuation, and convert to lower case
non_num = lambda x: re.sub(r'\d+', ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), '', x.lower())
remove_ws = lambda x: x.rstrip()

df['complaints'] = df['consumer_complaint_narrative'].map(non_num).map(punc_lower).map(remove_ws)

# %%
df['complaints'][29]
# Out:
# 'i transferred two fees on my loan a year ago i paid extra each month to target that balance by xxxx extra each month i noticed a balance transfer fee on my invoice and contacted the company to find out why i was being assessed am interest fee and a balance transfer fee i was told that the promotion had needed and i still owed almost the entire transfer that i did when i opened my credit card i explained to xxxx that cant be possible when i have never paid the monthly payment i always paid more like xxxx more each month she told me the extra money each month goes to the interest on the current balance i told her how is that fair to the customer and how the heck do i pay the balance transfer off if i as the consumer can not pay down the balance nor can i see the breakdown when i make a payment she was rude did not want to understand how their practices are misleading to the consumer and not fair i asked to speak with her supervisor which she transferred the call to xxxx who was more pleasant and agreed to waive the fees that were assessed i am writing to you to investigate this institutions process to ensure consumers and not mislead and taking advantage of'

# %%
df['consumer_complaint_narrative'][29]
# Out:
# 'I transferred two fees on my loan a year ago. I paid extra each month to target that balance by XXXX extra each month. I noticed a balance transfer fee on my invoice and contacted the company to find out why I was being assessed am Interest fee and a balance transfer fee. I was told that the promotion had needed and I still owed almost the entire transfer that I did when I opened my credit card!! I explained to XXXX that cant be possible when I have never paid the monthly payment I always paid more. Like XXXX more each month. She told me the extra money each month goes to The interest on the current balance. I told her how is that fair to the customer and how the heck do I pay the balance transfer off if I as the consumer can not pay down the balance nor can I see the breakdown when I make a payment!!! She was rude did not want to understand how their practices are misleading to the consumer and not fair!! I asked to speak with her Supervisor, which she transferred the call to XXXX who was more pleasant and agreed to waive the fees that were assessed. I am writing to you to investigate this institutions process to ensure consumers and not mislead and taking advantage of!!'

# %% [markdown]
# ### Tokenization

# %%
def tokenize_text(row):
    temp_tokenized_txt = word_tokenize(row['complaints'])
    return temp_tokenized_txt

# %%
df['complaints'] = df['complaints'].apply(word_tokenize)

# %%
df.loc[29,'complaints']
# Out:
# ['i',
#  'transferred',
#  'two',
#  'fees',
#  'on',
#  'my',
#  'loan',
#  'a',
#  'year',
#  'ago',
#  'i',
#  'paid',
#  'extra',
#  'each',
#  'month',
#  'to',
#  'target',
#  'that',
#  'balance',
#  'by',
#  'xxxx',
#  'extra',
#  'each',
#  'month',
#  'i',
#  'noticed',
#  'a',
#  'balance',
#  'transfer',
#  'fee',
#  'on',
#  'my',
#  'invoice',
#  'and',
#  'contacted',
#  'the',
#  'company',
#  'to',
#  'find',
#  'out',
#  'why',
#  'i',
#  'was',
#  'being',
#  'assessed',
#  'am',
#  'interest',
#  'fee',
#  'and',
#  'a',
#  'balance',
#  'transfer',
#  'fee',
#  'i',
#  'was',
#  'told',
#  'that',
#  'the',
#  'promotion',
#  'had',
#  'needed',
#  'and',
#  'i',
#  'still',
#  'owed',
#  'almost',
#  'the',
#  'entire',
#  'transfer',
#  'that',
#  'i',
#  'did',
#  'when',
#  'i',
#  'opened',
#  'my',
#  'credit',
#  'card',
#  'i',
#  'explained',
#  'to',
#  'xxxx',
#  'that',
#  'cant',
#  'be',
#  'possible',
#  'when',
#  'i',
#  'have',
#  'never',
#  'paid',
#  'the',
#  'monthly',
#  'payment',
#  'i',
#  'always',
#  'paid',
#  'more',
#  'like',
#  'xxxx',
#  'more',
#  'each',
#  'month',
#  'she',
#  'told',
#  'me',
#  'the',
#  'extra',
#  'money',
#  'each',
#  'month',
#  'goes',
#  'to',
#  'the',
#  'interest',
#  'on',
#  'the',
#  'current',
#  'balance',
#  'i',
#  'told',
#  'her',
#  'how',
#  'is',
#  'that',
#  'fair',
#  'to',
#  'the',
#  'customer',
#  'and',
#  'how',
#  'the',
#  'heck',
#  'do',
#  'i',
#  'pay',
#  'the',
#  'balance',
#  'transfer',
#  'off',
#  'if',
#  'i',
#  'as',
#  'the',
#  'consumer',
#  'can',
#  'not',
#  'pay',
#  'down',
#  'the',
#  'balance',
#  'nor',
#  'can',
#  'i',
#  'see',
#  'the',
#  'breakdown',
#  'when',
#  'i',
#  'make',
#  'a',
#  'payment',
#  'she',
#  'was',
#  'rude',
#  'did',
#  'not',
#  'want',
#  'to',
#  'understand',
#  'how',
#  'their',
#  'practices',
#  'are',
#  'misleading',
#  'to',
#  'the',
#  'consumer',
#  'and',
#  'not',
#  'fair',
#  'i',
#  'asked',
#  'to',
#  'speak',
#  'with',
#  'her',
#  'supervisor',
#  'which',
#  'she',
#  'transferred',
#  'the',
#  'call',
#  'to',
#  'xxxx',
#  'who',
#  'was',
#  'more',
#  'pleasant',
#  'and',
#  'agreed',
#  'to',
#  'waive',
#  'the',
#  'fees',
#  'that',
#  'were',
#  'assessed',
#  'i',
#  'am',
#  'writing',
#  'to',
#  'you',
#  'to',
#  'investigate',
#  'this',
#  'institutions',
#  'process',
#  'to',
#  'ensure',
#  'consumers',
#  'and',
#  'not',
#  'mislead',
#  'and',
#  'taking',
#  'advantage',
#  'of']

# %% [markdown]
# ### Remove non-English Words

# %%
words = set(nltk.corpus.words.words())  #set of English words 

df['complaints'] = df['complaints'].apply(lambda x: [item for item in x if item in words])

# %% [markdown]
# ### Remove Stop Words

# %%
words = ['i', 'im', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", 
         "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 
         'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',
         'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 
         'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 
         'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'other', 'another', 'and', 'but','if', 'or', 
         'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between',
         'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 
         'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 
         'where', 'why','how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 
         'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
         'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 
         'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn',
         "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn',
         "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', 
         "won't", 'wouldn', "wouldn't", 'times', 'keep', 'keeping', 'kept', 'tell', 'told', 'telling', 'ask',
         'asked', 'feel', 'go', 'went', 'going', 'write', 'wrote', 'writing', 'say', 'saying', 'said', 'call',
        'called', 'calling', 'x', 'xx', 'xxx', 'xxxx', 'xxxxx', 'xxxxxx', 'xxxxxxx', 'xxxxxxxx', 'dont', 
         'never', 'need', 'really', 'try', 'tried', 'trying', 'ill', 'would', 'upon', 'via', 'however', 
         'within', 'either', 'neither', 'chase', 'jp morgan chase', 'want', 'like', 'one', 'two', 'three', 
         'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'nothing', 'everything', 'anyway', 'suppose', 
        'supposed', 'day', 'discover', 'citi', 'wells', 'fargo', 'bmo', 'hsbc', 
         'equifax', 'pnc', 'td', 'ally', 'able', 'didnt', 'day', 'month', 'year']

# %%
company_list = df['company'].unique().tolist()
company_list2 = [x.lower() for x in company_list]

# %%
words = words + company_list2
words
# Out:
# ['i',
#  'im',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'other',
#  'another',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'times',
#  'keep',
#  'keeping',
#  'kept',
#  'tell',
#  'told',
#  'telling',
#  'ask',
#  'asked',
#  'feel',
#  'go',
#  'went',
#  'going',
#  'write',
#  'wrote',
#  'writing',
#  'say',
#  'saying',
#  'said',
#  'call',
#  'called',
#  'calling',
#  'x',
#  'xx',
#  'xxx',
#  'xxxx',
#  'xxxxx',
#  'xxxxxx',
#  'xxxxxxx',
#  'xxxxxxxx',
#  'dont',
#  'never',
#  'need',
#  'really',
#  'try',
#  'tried',
#  'trying',
#  'ill',
#  'would',
#  'upon',
#  'via',
#  'however',
#  'within',
#  'either',
#  'neither',
#  'chase',
#  'jp morgan chase',
#  'want',
#  'like',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nothing',
#  'everything',
#  'anyway',
#  'suppose',
#  'supposed',
#  'day',
#  'discover',
#  'citi',
#  'wells',
#  'fargo',
#  'bmo',
#  'hsbc',
#  'equifax',
#  'pnc',
#  'td',
#  'ally',
#  'resurgent capital services l.p.',
#  'synchrony financial',
#  'sterling jewelers, inc.',
#  'bank of america, national association',
#  'navient solutions, llc.',
#  'jpmorgan chase & co.',
#  'onemain financial holdings, llc.',
#  "merchants' credit guide company",
#  'fifth third financial corporation',
#  'ldf holdings, llc',
#  'citibank, n.a.',
#  'convergent resources, inc.',
#  'freedom mortgage company',
#  'nationstar mortgage',
#  'retrieval-masters creditors bureau, inc., elmsford, ny branch',
#  'commerce bank',
#  'experian information solutions inc.',
#  'dynamic recovery solutions, llc',
#  'encore capital group inc.',
#  'contract callers inc',
#  'diversified consultants, inc.',
#  'atlanticus services corporation',
#  'aes/pheaa',
#  'navy federal credit union',
#  'national recoveries, inc.',
#  'bmo harris bank national association',
#  'discover bank',
#  'barclays bank delaware',
#  'national credit systems,inc.',
#  'select portfolio servicing, inc.',
#  'wells fargo & company',
#  'shellpoint partners, llc',
#  'opportunity financial, llc',
#  'sunrise credit services, inc',
#  'wallace management company, llc',
#  'google compare credit cards inc.',
#  'rushmore loan management services llc',
#  'paypal holdings, inc',
#  'alliance data card services',
#  'first community mortgage, inc.',
#  'afni inc.',
#  'sherloq group, inc',
#  'hsbc north america holdings inc.',
#  'phoenix financial services llc',
#  'southern management systems inc.',
#  'united services automobile association',
#  'capital one financial corporation',
#  'halsted financial services, llc.',
#  'specialized loan servicing holdings llc',
#  'transworld systems inc',
#  'cng financial corporation',
#  'equifax, inc.',
#  'regions financial corporation',
#  'citizens financial group, inc.',
#  'bbva financial corporation',
#  'nationwide credit & collection, inc.',
#  'receivables performance management, llc',
#  'cmre financial services, inc.',
#  'ccs financial services, inc.',
#  'pnc bank n.a.',
#  'general motors financial company, inc.',
#  'western union company, the',
#  'united collection bureau, inc.',
#  'the outsource group, inc',
#  'midfirst bank',
#  'toyota motor credit corporation',
#  'blitt and gaines, p.c.',
#  'loancare, llc',
#  'u.s. bancorp',
#  'american express company',
#  'american honda finance corp',
#  'wyndham capital mortgage, inc.',
#  'collection professionals inc (illinois)',
#  'portfolio recovery associates inc',
#  'first national collection bureau, inc.',
#  'franklin collection service, inc.',
#  'populus financial group, inc. (f/k/a ace cash express)',
#  'tcf national bank',
#  'land home financial services',
#  'f.h. cann & associates, inc.',
#  'roundpoint mortgage servicing corporation',
#  'coinbase, inc.',
#  'jpl recovery llc',
#  'williams & fudge, inc',
#  'a.c.s. companies, inc. i',
#  'consumer portfolio services, inc.',
#  'acs education services',
#  'unlimited progress corp',
#  'credit bureau of carbon county',
#  'servis one, inc., titusville, pa branch',
#  'pro com services of illinois, inc.',
#  'square inc.',
#  'edfinancial services',
#  'community loan servicing, llc (formerly known as bayview loan servicing, llc)',
#  'robinhood markets inc.',
#  'nationwide acceptance llc',
#  'fay servicing, llc',
#  'exeter finance corp.',
#  'harvard collections, llc',
#  'statebridge company',
#  'ally financial inc.',
#  'flagstar bank, fsb',
#  'source receivables management llc',
#  'carrington mortgage services, llc',
#  'rocket mortgage, llc',
#  'netspend corporation',
#  'americash holding llc',
#  'trueaccord corp.',
#  'ocwen financial corporation',
#  'parkside lending, llc',
#  'hyundai capital america',
#  'national check resolution inc.',
#  'transunion intermediate holdings, inc.',
#  'credit bureau services association',
#  'national credit adjusters, llc',
#  'td bank us holding company',
#  'merchants credit llc',
#  'jtm capital management, llc',
#  'ability recovery services, llc',
#  'first midwest bancorp, inc.',
#  'huntington national bank, the',
#  'national collection systems, inc.',
#  'municipal collections services, inc.',
#  'fair collections & outsourcing, inc.',
#  'credit collection partners, inc.',
#  'erc',
#  'usi solutions inc.',
#  'the bureaus, inc.',
#  'armor systems corporation',
#  'harris & harris, ltd.',
#  'ld holdings group, llc',
#  'bridgecrest acceptance corporation',
#  'chime financial inc',
#  'bb&t corporation',
#  'dovenmuehle mortgage, inc.',
#  'world acceptance corporation',
#  'medical business bureau',
#  'united shore financial services, llc',
#  'resurgence legal group, pc',
#  'ditech financial llc',
#  'oliver adjustment co.',
#  'total loan company, llc',
#  'byrider franchising, llc',
#  'midcountry financial corp',
#  'wakefield & associates, inc.',
#  'allied international credit corp., (us)',
#  'midwest recovery systems',
#  'guaranteed rate inc.',
#  'truist financial corporation',
#  'charles schwab corporation, the',
#  'santander consumer usa holdings inc.',
#  'pls group, inc',
#  'lakeview loan servicing, llc',
#  'sovereign lending group, incorporated',
#  'qc holdings inc',
#  'keynote consulting, inc.',
#  'the cmi group, inc.',
#  'caine & weiner company, inc.',
#  'turner acceptance corp.',
#  'ncb management services inc.',
#  'neighborhoods united, llc',
#  'amerisave mortgage corporation',
#  'credit acceptance corporation',
#  'eagle recovery associates, inc.',
#  'axos financial, inc.',
#  'goldman sachs bank usa',
#  'vw credit',
#  'sequium asset solutions, llc',
#  'credit bureau collection services, inc.',
#  'carmax, inc.',
#  'nelnet, inc.',
#  'midstate collection solutions, inc.',
#  'global resolution group, llc',
#  'i.q. data international, inc.',
#  'selene finance lp',
#  'umb financial corporation',
#  'sarma',
#  'reliant financial corporation',
#  'jpl recovery solutions',
#  'kinum, inc., indianapolis, in branch',
#  'the receivable management services llc',
#  'bam management us holdings inc.',
#  'iowa student loan liquidity corporation',
#  'diversified adjustment service, inc.',
#  'cottonwood financial ltd.',
#  'douglas, chancellor, meyers and associates, llc',
#  'nissan motor acceptance corporation',
#  'lj ross associates',
#  'credence resource management, llc',
#  'conduent incorporated',
#  'automated accounts management services',
#  'coast professional inc',
#  'receivables management partners, llc',
#  'das acquisition company, llc',
#  'american profit recovery, inc., marlborough, ma branch',
#  'cl holdings llc',
#  'merchants and medical credit corporation, inc.',
#  'manley deas & kochalski llc',
#  'amcol systems, inc.',
#  'kentucky higher education assistance authority',
#  'arvest bank group, inc.',
#  'suntrust banks, inc.',
#  'alorica inc.',
#  'amerihome mortgage company, llc',
#  'moneygram payment systems worldwide inc',
#  'american internet mortgage',
#  'lending club corp',
#  'heartland payment systems inc',
#  'bsi financial holdings, inc.',
#  'crosscountry mortgage llc',
#  'cavalry investments, llc',
#  'mandarich law group, llp',
#  'apo llc',
#  'rockford mercantile agency, inc.',
#  'southwest credit systems, l.p.',
#  'caliber home loans, inc.',
#  'i.c. system, inc.',
#  'first national bank of omaha',
#  'american coradius international llc',
#  'first merchants corporation',
#  'professional placement services, llc',
#  'early warning services, llc',
#  'sun loan company inc.',
#  't.s. holdings',
#  'alliance collection agencies, inc.',
#  'springleaf finance corporation',
#  'colony brands, inc.',
#  'scott fetzer financial group inc.',
#  'fma alliance, ltd.',
#  'incomm holdings inc.',
#  'blackhawk network holdings inc.',
#  'radius global solutions llc',
#  'credit control, llc',
#  'ghidotti | berger llp',
#  'bluechip financial',
#  'pendrick capital partners holding, llc',
#  'vengroff williams, inc',
#  'curo intermediate holdings',
#  'linebarger goggan blair & sampson llp',
#  'sonnenschein financial services, inc.',
#  'hcfs health care financial services, inc.',
#  'phh mortgage services corporation',
#  'credit protection association, l.p.',
#  'sra associates, inc.',
#  'rosebud economic development corporation',
#  'edvantage llc',
#  'prosper marketplace, inc.',
#  'riverwalk financial corporation',
#  'nra group, llc',
#  'state collection service, inc.',
#  'hw holding, inc',
#  'pentagon federal credit union',
#  'oportun financial corporation',
#  'chrysalis holdings llc',
#  'eos holdings, inc.',
#  'minto financial dba minto money',
#  'comerica',
#  'clark county collection service',
#  'associated banc-corp',
#  'commonwealth financial systems, inc.',
#  'aargon agency, inc.',
#  'illinois collection service, inc.',
#  'onemain finance corporation',
#  'org gc gp buyer, llc',
#  'law office of michael r naughton',
#  'ama advisors, llc.',
#  'absolute resolutions corp.',
#  'prestige financial services inc',
#  'great lakes',
#  'genesis financial & payment systems holdings, llc',
#  'keycorp',
#  'global asset management group, inc.',
#  'ars national services, inc.',
#  'harley davidson financial services inc',
#  'first technology federal credit union',
#  'atg credit, llc',
#  'moneylion inc.',
#  'mountain run solutions, llc',
#  'real time group, inc.',
#  'slm corporation',
#  'mrs bpo, llc',
#  'komyatte & casbon, p.c.',
#  'vander financial, llc',
#  'collection professionals, inc. (macomb, il)',
#  'markoff law llc',
#  'arnold scott harris, p.c.',
#  'pennymac loan services, llc.',
#  'paradigm assets, llc',
#  'avadyne health holdings, inc',
#  'alliant credit union',
#  'select management resources, llc',
#  'performant financial corporation',
#  'tiaa, fsb',
#  'monterey financial services llc',
#  'selene holdings llc',
#  'remitly, inc.',
#  'aspen national financial, inc.',
#  'millco management',
#  'nicholas financial inc.',
#  'ecmc group, inc.',
#  'diverse funding associates llc',
#  'enova international, inc.',
#  'e*trade bank',
#  'miramed revenue group llc',
#  'singlepoint gi',
#  'innovate managed holdings, llc',
#  'debt recovery solutions, llc',
#  'card corporation',
#  'flandreau santee sioux tribe',
#  'n26 inc.',
#  'self financial inc.',
#  'eastern account systems of connecticut, inc.',
#  'first advantage lns inc.',
#  'big picture loans, llc',
#  'planet home lending, llc',
#  'greensky, llc',
#  'healthcare receivables group, inc.',
#  'amos financial llc',
#  'state farm bank, fsb',
#  'account resolution corporation',
#  'critical resolution mediation llc',
#  'tekcollect inc.',
#  'better mortgage, inc.',
#  'cardinal financial company',
#  'online information services, inc.',
#  'oklahoma student loan authority',
#  'central portfolio control inc.',
#  'financial business and consumer solutions.',
#  'c/c financial',
#  'second round limited partnership, austin, tx branch',
#  'resurgence financial, llc',
#  "dyck-o'neal, inc.",
#  'meridian financial services, inc.',
#  'smith, cohen & rosenberg llc',
#  'american credit acceptance, llc',
#  'social finance, inc.',
#  'iqor us inc',
#  'velocity portfolio group',
#  'upstart holdings, inc.',
#  'first data corporation',
#  'nelson cruz & associates llc',
#  'leader one financial corporation',
#  'brightfunders, llc',
#  'activehours',
#  'wlcc',
#  'amsher collection services, inc.',
#  'torres credit services, inc.',
#  'xoom corporation',
#  'mariner finance, llc',
#  'united revenue corporation',
#  'nationwide credit corporation',
#  'collection bureau of america ltd.',
#  'crossroads systems inc.',
#  'paramount recovery systems, l.p.',
#  'synovus bank',
#  'yamaha motor finance corporation usa',
#  'duvera billing services, llc',
#  'cashcall, inc.',
#  'tower loan of mississippi, inc.',
#  'mortgage connect lp',
#  'capital accounts, llc',
#  'oasis legal finance holding company, llc',
#  'glass mountain capital, llc',
#  'm&t bank corporation',
#  'kohn law firm s.c.',
#  'certified services, inc.',
#  'simm associates, inc.',
#  'american pacific mortgage',
#  'mortgage research center, llc',
#  'winklevoss exchange llc',
#  'meade & associates, inc.',
#  'bco consulting services',
#  'benuck & rainey, inc.',
#  'uscb corporation',
#  'tri-state adjustments, inc.',
#  'weltman, weinberg & reis co., l.p.a.',
#  'revco management, llc',
#  'lockhart, morris & montgomery inc.',
#  'diaz anselmo lindberg, p.a.',
#  'guild mortgage company llc',
#  'credit karma, llc',
#  'gva holdings, llc',
#  'rgs financial, inc.',
#  'northstar location services, llc',
#  'credit card receivables fund incorporated',
#  'bankers healthcare group llc',
#  'avant credit corporation',
#  'associated credit services, inc.',
#  'earnest inc.',
#  'filo mortgage, l.l.c.',
#  'rentdebt automated collections, llc',
#  'procollect, inc.',
#  'fairway independent mortgage corporation',
#  'first portfolio servicing inc',
#  'first financial bancorp',
#  'capital management services, lp',
#  'complete professional recovery llc',
#  'mohela',
#  'coastal credit, llc',
#  'upgrade, inc.',
#  'cibc bancorp usa inc.',
#  'americollect',
#  'kashia services',
#  'jfq lending, inc.',
#  'pressler & pressler, llp',
#  'acima credit, llc',
#  'mercedes benz financial services',
#  'proficio financial services, llc',
#  'first citizens bancshares, inc.',
#  'stearns ventures, llc',
#  'lexisnexis',
#  'collins & hilton asset group, llc',
#  'global portfolio recovery, llc',
#  'westlake services, llc',
#  'angel oak home loans llc',
#  'busey bank',
#  'rozlin financial group, inc.',
#  'wsfs financial corporation',
#  'transferwise ltd',
#  'nationwide recovery systems, ltd',
#  'stuart-lippman and associates, inc',
#  'consumer financial services',
#  'east west bank',
#  'village capital & investment llc',
#  'reverse mortgage investment tr',
#  'foris dax, inc.',
#  'dependon collection service inc',
#  'river city mortgage llc',
#  'united check recovery bureau, inc.',
#  'west coast servicing, inc.',
#  'associated collectors, inc.',
#  'finco services inc dba current',
#  'alliant capital management llc',
#  'sentry credit, inc.',
#  'dfc global corp.',
#  'northwest collectors inc.',
#  'lpsg',
#  'self lender inc',
#  'samc honebee trs, llc',
#  'betterment llc',
#  'omega rms, llc',
#  'tmx finance llc',
#  'heavner, beyers & mihlar llc',
#  'collections acquisition company, inc.',
#  'first associates loan servicing llc',
#  'market place mortgage corp.',
#  'capital alliance financial, llc',
#  'travelex ny, inc.',
#  'falls collection service inc.',
#  'first centennial mortgage corp',
#  'medical data systems, inc.',
#  'universal account servicing, llc',
#  'arm professional services llc',
#  'syncapay, inc',
#  'american credit systems, inc',
#  'gfs ii, llc',
#  'sofi mortgage, llc',
#  'ad astra recovery services inc',
#  'first midwest financial',
#  'banco popular de puerto rico',
#  'sun west mortgage company, inc.',
#  'computer sciences corporation',
#  'th professional & medical collections ltd',
#  'total card, inc.',
#  'jh portfolio debt equities, llc',
#  'mccarthy, burgess & wolff, inc.',
#  'consumer collection management. inc',
#  'perfection collection',
#  'cawley & bergmann, llp',
#  'troy capital, llc',
#  'benworth capital partners llc',
#  'pronto finance inc.',
#  'happy money, inc.',
#  'professional finance company, inc.',
#  'n.a.r., inc.',
#  'webster bank, national association',
#  'continental services group, inc. d/b/a conserve',
#  'jim bottin enterprises, inc',
#  'earm llc',
#  'pacific western bank',
#  'central collection corporation',
#  'risecredit, llc',
#  'ford motor credit co.',
#  'novad management consulting llc',
#  'financial asset management systems, inc.',
#  'check into cash inc.',
#  'credit corp solutions inc.',
#  'focus holding company',
#  'affiliate asset solutions, llc',
#  'forest recovery services llc',
#  'truhome solutions, llc',
#  'ridge & valley realty, inc.',
#  'fiserv inc.',
#  'worldremit corp.',
#  'synergy one lending, inc.',
#  'nations direct mortgage, llc',
#  'walwick, inc',
#  'united panam financial corp.',
#  'vanderbilt mortgage & finance, inc',
#  'carvana group, llc',
#  'the cbe group, inc.',
#  'capio partners, llc',
#  'okcoin usa inc.',
#  'allied collection services, inc. (nevada)',
#  'clearpath lending',
#  'client services, inc.',
#  'bcb investments llc',
#  'access group inc.',
#  'financial services of america',
#  'medical-commercial audit inc',
#  'a.r.m. solutions, inc.',
#  'applied data finance, llc',
#  'premier\xa0student\xa0loan\xa0center',
#  'fci lender services inc.',
#  'complete credit solutions, inc.',
#  'ltd financial services, lp',
#  'first investors servicing corporation, atlanta, ga branch',
#  'municipal collections of america inc.',
#  'valor intelligent processing, llc',
#  'waypoint resource group, llc',
#  'utah system of higher education',
#  "creditors' protection service, inc.",
#  'zingo cash illinois llc',
#  'northwood asset management group',
#  'service finance holdings, llc',
#  'ria financial',
#  'cresco capital inc.',
#  'sequoia financial services',
#  'miller and steeno, p.c.',
#  'home point financial corporation',
#  'braufmann, leighmann & associates',
#  'mcneil & meyers asset management group, llc',
#  'account liquidation services inc.',
#  'penn credit corporation',
#  'security credit systems inc',
#  'mj altman companies, inc.',
#  'security credit services, llc',
#  'logicoll, llc',
#  'commercial recovery systems',
#  'circle internet financial',
#  'movement mortgage llc',
#  'interfirst mortgage company',
#  'professional bureau of collections of maryland, inc., greenwood village, co branch',
#  'the barton law group, llc',
#  'professional credit analysts of mn, inc.',
#  'sf vago, llc',
#  'sn servicing corporation',
#  'account recovery service, inc. (wi)',
#  'wilber and associates, p.c.',
#  'd&a services, llc',
#  'rowland avenue management, inc. a/ka columbia debt recovery, llc d/b/a genesis',
#  'fairway capital recovery, llc',
#  'manhattan beach venture, llc',
#  'data-central, llc',
#  'drive now acceptance llc',
#  'plaza home mortgage, inc.',
#  'constar financial services, llc',
#  'castle credit co holdings, llc, chicago, il branch',
#  'advance america, cash advance centers, inc.',
#  'curfin holding company, inc',
#  'ac autopay, llc, denver, co branch',
#  'tidewater finance company, inc.',
#  'tribal lending enterprise, inc.',
#  'international computer systems, inc.',
#  'certegy holdings, llc',
#  'oracle financial group llc.',
#  'riverwalk financial corporation',
#  'patrick k willis company inc',
#  'capitol credit services, inc',
#  'national credit services, inc.',
#  'fidelity national information services, inc. (fnis)',
#  'seattle service bureau, inc',
#  'firstsource business process services, llc',
#  'zarvad iii s.a.',
#  'asset recovery solutions, llc',
#  'america’s financial choice, inc.',
#  'action financial services, llc',
#  'american first finance, inc.',
#  'genesis fs card services, inc.',
#  'pinnacle recovery, inc.',
#  'duncan solutions, lnc.',
#  'the law offices of mitchell d. bluhm & associates',
#  'aspen yo llc',
#  'ideal collection services, inc.',
#  'thaxton investment corporation',
#  'cedars business services, llc',
#  'local data recovery, llc',
#  'mark a. kirkorsky, pc',
#  'flat branch mortgage, inc.',
#  'the wilber law firm, p.c.',
#  'a/r concepts, inc.',
#  'rms-recovery management services, inc.',
#  'capital markets cooporative, llc',
#  'midwest credit & collection, inc.',
#  'atlantic credit & finance, inc.',
#  'frost-arnett company',
#  "people's united bank, national association",
#  'corelogic inc',
#  'draper and kramer mortgage corp.',
#  'strategic alliances, inc.',
#  'four directions lending llc',
#  'c & m associates group, inc.',
#  'jnr adjustment company, inc',
#  'cng holdings inc',
#  'skrill usa, inc.',
#  'clearline loans llc',
#  'debtsy holdings, inc.',
#  'uplift, inc',
#  'automated collection services, inc.',
#  'dlc, llc',
#  'cit bank, national association',
#  'grant & weber',
#  'student loan financial assistance',
#  'manor resources, llc',
#  'choice recovery, inc.',
#  'fair financial corp.',
#  'stevens business service, inc.',
#  'fidelity national financial, inc',
#  'rent recover, llc',
#  'mufg americas holdings corporation',
#  'kgw corporation',
#  'mobiloans, llc',
#  "conn's, inc.",
#  'asg solutions llc',
#  'united resource systems, inc',
#  'bank of the west',
#  'ncc business services, inc.',
#  'receivables management group, inc. (mn)',
#  'a & o recovery solutions, llc',
#  'prince parker & associates',
#  'pldr',
#  'states recovery systems, inc.',
#  'diaz & associates, inc.',
#  'chicago car center, inc.',
#  'newman, hesse & associates, p. a.',
#  'financial corporation of america',
#  'adler wallach & associates, inc.',
#  'brown and joseph, ltd',
#  'red cedar services, inc',
#  'westcreek financial',
#  'american financial resources, inc.',
#  'provident funding associates',
#  'global credit & collection corporation',
#  'alpha recovery corp',
#  'panorama mortgage group, llc',
#  'new century auto sales, inc.',
#  'money source, the',
#  'union home mortgage corp',
#  'fc holdco llc',
#  'wheels financial group, llc.',
#  'integrated asset recovery llc',
#  'persolve, llc - legal - series 2',
#  'the stark collection agency, inc.',
#  'general credit services',
#  'emerald coast collections, llc',
#  'autobank financial, llc',
#  'rent recovery solutions',
#  'v and h portfolio',
#  'neighborhood assistance corporation of america ("naca")',
#  'investigation & recovery assoc. llc',
#  'trident asset management, l.l.c.',
#  'urs holding, llc',
#  'tfs financial corporation',
#  'endpoint resolution services (ers)',
#  'finance of america holdings llc',
#  'american advisors group',
#  'siwell inc',
#  'cumulus funding llc',
#  'crown mortgage co.',
#  'grant mercantile agency',
#  'compass mortgage, inc.',
#  'mezu, inc',
#  'arbor professional solutions, inc.',
#  'ingo money, inc.',
#  'american payment holdco, inc.',
#  'malcolm s. gerald and associates, inc.',
#  'illinois lending corporation',
#  'revenue enterprises, llc',
#  'zwicker & associates',
#  'college ave student loan servicing, llc',
#  'mb financial, inc.',
#  'redfin corporation',
#  'nations lending corporation',
#  'direct recovery services, llc',
#  'american neighborhood mortgage',
#  'id analytics, inc.',
#  'firstbank puerto rico',
#  'trinity financial services, llc',
#  'residentcollect, inc.',
#  'new hampshire higher education loan corporation',
#  'webcollex, llc',
#  'republic credit indemnity companies, inc.',
#  'home loan center, inc.',
#  'mne services, inc',
#  'immediate credit recovery',
#  'old republic national title holding co.',
#  'the shindler law firm',
#  'professional receivables network',
#  'future finance company',
#  'southwest recovery services, inc.',
#  'overland bond & investment corporation',
#  'old national bank',
#  'broker solutions, inc.',
#  '21st mortgage corp.',
#  'klarna ab',
#  'bth management',
#  'kimball, tirey & st. john llp',
#  'roseberry inc.',
#  'continental finance company, llc',
#  'fig tech inc.',
#  'capital link management, llc',
#  'northern trust company, the',
#  'debt relief center',
#  'pacific foresight financial corporation',
#  'paramount gr holdings, llc',
#  'nam national arbitration and mediation',
#  'lennar financial services, llc',
#  'avant holding company, inc.',
#  'the money company',
#  'account control technology, inc.',
#  'crown asset management, llc, duluth, ga branch',
#  'creditors collection bureau, inc.',
#  'ascendium education group',
#  'merchants and professional bureau, inc.',
#  'avante',
#  'auto trakk, llc',
#  'ameritech financial',
#  'mercantile adjustment bureau, llc',
#  'lco financial services, llc',
#  'compass recovery group, llc',
#  'recovery solutions group, llc',
#  'maury cobb, attorney at law, llc']

# %%
df['complaints'] = df['complaints'].apply(lambda x: [item for item in x if item not in words])

# %%
df['complaints'][507]
# Out:
# ['applied',
#  'loan',
#  'modification',
#  'due',
#  'illness',
#  'problem',
#  'freedom',
#  'update',
#  'lender',
#  'find',
#  'phone',
#  'make',
#  'approval',
#  'freedom',
#  'mortgage',
#  'law',
#  'send',
#  'pending',
#  'modification',
#  'update',
#  'first',
#  'class',
#  'mail',
#  'every',
#  'agent',
#  'speak',
#  'freedom',
#  'mortgage',
#  'law',
#  'last',
#  'notice',
#  'receive',
#  'mail',
#  'state',
#  'title',
#  'search',
#  'intentionally',
#  'fail',
#  'struggle',
#  'trial',
#  'period',
#  'date',
#  'payment',
#  'new',
#  'loan',
#  'make',
#  'complaint',
#  'freedom',
#  'bad',
#  'start',
#  'send',
#  'loss',
#  'mitigation',
#  'start',
#  'due',
#  'today',
#  'freedom',
#  'law',
#  'loan',
#  'number']

# %%
df['complaints'][2549]
# Out:
# ['complaint',
#  'bank',
#  'response',
#  'address',
#  'actual',
#  'complaint',
#  'previous',
#  'issue',
#  'ago',
#  'bank',
#  'new',
#  'platform',
#  'issue',
#  'currently',
#  'product',
#  'defect',
#  'banking',
#  'platform',
#  'deposit',
#  'business',
#  'account',
#  'detail',
#  'batch',
#  'see',
#  'attach',
#  'example',
#  'several',
#  'miss',
#  'report',
#  'back',
#  'spend',
#  'long',
#  'could',
#  'figure',
#  'tool',
#  'issue',
#  'extremely',
#  'significant',
#  'lead',
#  'business',
#  'inaccurate',
#  'accounting',
#  'billing',
#  'incorrectly',
#  'speak',
#  'woman',
#  'confirm',
#  'product',
#  'defect',
#  'work',
#  'digital',
#  'team',
#  'get',
#  'problem',
#  'fix',
#  'phone',
#  'leave',
#  'executive',
#  'office',
#  'several',
#  'response',
#  'bank',
#  'misrepresent',
#  'accurate',
#  'business',
#  'bank',
#  'account',
#  'end']

# %% [markdown]
# ### Stemming

# %%
#def stem_text(text):
#    doc_stemmed = []
#    stemmer = LancasterStemmer()
    
#    for word in text:
#        doc_stemmed.append(stemmer.stem(word))
        
#    return doc_stemmed

# %%
# df['complaints'] = df['complaints'].apply(stem_text)

# %% [markdown]
# Since stemming can make words hard to interpret, this step is skipped for now.

# %% [markdown]
# ### Parts of Speech

# %%
#tagging words with parts of speech 
df['complaints_tagged'] = pos_tag_sents(df['complaints'].tolist())

# %%
#inspect tagged words for one abstract
df['complaints_tagged'][1]
# Out:
# [('receive', 'JJ'),
#  ('phone', 'NN'),
#  ('handle', 'NN'),
#  ('case', 'NN'),
#  ('hung', 'NN'),
#  ('didnt', 'NN'),
#  ('anything', 'NN'),
#  ('depth', 'JJ'),
#  ('anything', 'NN'),
#  ('receive', 'JJ'),
#  ('letter', 'NN'),
#  ('today', 'NN'),
#  ('speak', 'VB'),
#  ('card', 'NN'),
#  ('true', 'JJ'),
#  ('lie', 'JJ'),
#  ('letter', 'NN'),
#  ('send', 'VBP'),
#  ('letter', 'NN'),
#  ('basically', 'RB'),
#  ('lie', 'JJ'),
#  ('inform', 'NN'),
#  ('take', 'VB'),
#  ('case', 'NN'),
#  ('hung', 'NN'),
#  ('else', 'RB')]

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %% [markdown]
# ### Lemmatization

# %%
wordNetLemmatizer = WordNetLemmatizer()

# %%
#creating a function to convert post_tags to WordNet friendly tags, then lemmatizing
def lemmatize_all(tagged_text):
    doc_lemm = []
    wnl = WordNetLemmatizer()
    for word, tag in (tagged_text):
        if tag.startswith("NN"):
            doc_lemm.append(wnl.lemmatize(word, wordnet.NOUN))
        elif tag.startswith('VB'):
            doc_lemm.append(wnl.lemmatize(word, wordnet.VERB))
        elif tag.startswith('JJ'):
            doc_lemm.append(wnl.lemmatize(word, wordnet.ADJ))
        else:
            doc_lemm.append(word)
    return doc_lemm

# %%
df['complaints'] = df['complaints_tagged'].apply(lemmatize_all)

# %%
df.sample(5)
# Out:
#      date_received                      product  \
# 1496      06/17/20  Credit card or prepaid card
# 5680      04/11/19                     Mortgage
# 5048      08/19/20              Debt collection
# 2506      09/18/19                     Mortgage
# 463       06/08/21  Checking or savings account
#
#                                      sub-product  \
# 1496  General-purpose credit card or charge card
# 5680                                FHA mortgage
# 5048                                Medical debt
# 2506                  Conventional home mortgage
# 463                             Checking account
#
#                                    issue                          sub-issue  \
# 1496  Other features, terms, or problems                      Other problem
# 5680      Trouble during payment process                               None
# 5048  False statements or representation  Attempted to collect wrong amount
# 2506          Struggling to pay mortgage                               None
# 463                  Managing an account           Deposits and withdrawals
#
#                            consumer_complaint_narrative  \
# 1496  I am a long-term citi card holder ( gold card ...
# 5680  Since XX/XX/XXXX I have tried to dispute this ...
# 5048  I received a Delinquency Notification dated XX...
# 2506  To whom It may concern I am late 3 payment so ...
# 463   I opened a personal checking account with Axos...
#
#                                 company_public_response  \
# 1496  Company has responded to the consumer and the ...
# 5680  Company has responded to the consumer and the ...
# 5048                                               None
# 2506                                               None
# 463                                                None
#
#                        company zip_code            tags  \
# 1496            CITIBANK, N.A.    60657  Older American
# 5680  Freedom Mortgage Company    60060            None
# 5048     Harris & Harris, Ltd.    60030            None
# 2506       NATIONSTAR MORTGAGE    60804            None
# 463       AXOS FINANCIAL, INC.    60031            None
#
#          company_response_to_consumer timely_response?  consumer_disputed?  \
# 1496  Closed with non-monetary relief              Yes                 NaN
# 5680          Closed with explanation              Yes                 NaN
# 5048          Closed with explanation              Yes                 NaN
# 2506          Closed with explanation              Yes                 NaN
# 463           Closed with explanation              Yes                 NaN
#
#                                              complaints  \
# 1496  [card, holder, gold, card, end, end, rope, pho...
# 5680  [since, dispute, credit, bureau, course, accur...
# 5048  [receive, delinquency, notification, detail, b...
# 2506  [may, concern, late, payment, far, unable, use...
# 463   [personal, account, bank, time, registered, so...
#
#                                       complaints_tagged
# 1496  [(card, NN), (holder, NN), (gold, NN), (card, ...
# 5680  [(since, IN), (dispute, NN), (credit, NN), (bu...
# 5048  [(receive, JJ), (delinquency, NN), (notificati...
# 2506  [(may, MD), (concern, NN), (late, JJ), (paymen...
# 463   [(personal, JJ), (account, NN), (bank, NN), (t...

# %%
df['complaints'][29]
# Out:
# ['transfer',
#  'loan',
#  'year',
#  'ago',
#  'extra',
#  'month',
#  'target',
#  'balance',
#  'extra',
#  'month',
#  'balance',
#  'transfer',
#  'fee',
#  'invoice',
#  'company',
#  'find',
#  'assessed',
#  'interest',
#  'fee',
#  'balance',
#  'transfer',
#  'fee',
#  'promotion',
#  'still',
#  'almost',
#  'entire',
#  'transfer',
#  'credit',
#  'card',
#  'cant',
#  'possible',
#  'monthly',
#  'payment',
#  'always',
#  'month',
#  'extra',
#  'money',
#  'month',
#  'interest',
#  'current',
#  'balance',
#  'fair',
#  'customer',
#  'heck',
#  'pay',
#  'balance',
#  'transfer',
#  'consumer',
#  'pay',
#  'balance',
#  'see',
#  'breakdown',
#  'make',
#  'payment',
#  'rude',
#  'understand',
#  'mislead',
#  'consumer',
#  'fair',
#  'speak',
#  'supervisor',
#  'transfer',
#  'pleasant',
#  'agree',
#  'waive',
#  'ass',
#  'investigate',
#  'process',
#  'ensure',
#  'mislead',
#  'take',
#  'advantage']

# %%
df.to_csv('complaints_nlp.csv', index=False)
